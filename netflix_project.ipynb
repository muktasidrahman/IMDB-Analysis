# %% [markdown]
# # Loading python libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("C:\\Users\\mukta\\Desktop\\netflix\\netflix_data.csv")
df
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
df.rename(columns={ "listed_in": "genre"},inplace=True)

# %%
df.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 2  December 20, 2018          2011      R     78 min
# 3  November 16, 2017          2009  PG-13     80 min
# ...

# %%
df.drop(columns=[ "cast", "director", "description"],inplace=True)

# %% [markdown]
# Shows the numbers of columns and rows

# %%
df.shape
# Out:
# (7787, 9)

# %% [markdown]
# Shows the data types for the columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7787 entries, 0 to 7786
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7787 non-null   object
#  1   type          7787 non-null   object
#  2   title         7787 non-null   object
#  3   country       7280 non-null   object
#  4   date_added    7777 non-null   object
#  5   release_year  7787 non-null   int64
#  6   rating        7780 non-null   object
#  7   duration      7787 non-null   object
#  8   genre         7787 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 547.6+ KB

# %%
df["release_year"]= pd.to_numeric(df["release_year"])

# %%
df.isnull().sum()
# Out:
# show_id           0
# type              0
# title             0
# country         507
# date_added       10
# release_year      0
# rating            7
# duration          0
# genre             0
# dtype: int64

# %%
percent_missing = df.isnull().sum() * 100 / len(df)
percent_missing
# Out:
# show_id         0.000000
# type            0.000000
# title           0.000000
# country         6.510851
# date_added      0.128419
# release_year    0.000000
# rating          0.089893
# duration        0.000000
# genre           0.000000
# dtype: float64

# %%
variables = df.columns

count = []

for var in variables:
    length = df[var].count()
    count.append(length)
    
percent_missing = np.round(100 * pd.Series(count) / len(df), 2)
percent_missing
# Out:
# 0    100.00
# 1    100.00
# 2    100.00
# 3     93.49
# 4     99.87
# 5    100.00
# 6     99.91
# 7    100.00
# 8    100.00
# dtype: float64

# %%
plt.figure(figsize=(12,10))
plt.barh(variables,percent_missing)
plt.title("Percent of avaliable data", fontsize=14)
plt.xlabel("Percent of data ", fontsize=14)
plt.show()

# %%
#df["country"].fillna("Uknown", inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7787 entries, 0 to 7786
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7787 non-null   object
#  1   type          7787 non-null   object
#  2   title         7787 non-null   object
#  3   country       7280 non-null   object
#  4   date_added    7777 non-null   object
#  5   release_year  7787 non-null   int64
#  6   rating        7780 non-null   object
#  7   duration      7787 non-null   object
#  8   genre         7787 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 547.6+ KB

# %%
df["release_year"].describe()
# Out:
# count    7787.000000
# mean     2013.932580
# std         8.757395
# min      1925.000000
# 25%      2013.000000
# 50%      2017.000000
# 75%      2018.000000
# max      2021.000000
# Name: release_year, dtype: float64

# %%
count_category = pd.DataFrame(df["type"].value_counts().reset_index())
count_category.rename(columns={"index":"category", "type":"count"},inplace=True)
count_category
# Out:
#   category  count
# 0    Movie   5377
# 1  TV Show   2410

# %%
plt.figure(figsize=(10,12))
colors = ["beige", "crimson"]
plt.pie(count_category["count"], labels = count_category["category"], colors = colors, autopct='%1.2f%%', shadow=True, startangle=140)
plt.title("Percentage of Netflix contents ",fontsize=14)
plt.legend(count_category["category"], loc = "best")
plt.axis('equal', fontsize=14)
plt.show()
# Out:
# <ipython-input-242-c60960e0829e>:6: MatplotlibDeprecationWarning: Passing unsupported keyword arguments to axis() will raise a TypeError in 3.3.
#   plt.axis('equal', fontsize=14)

# %%
ratings_count = pd.DataFrame(df["rating"].value_counts().reset_index())
ratings_count.rename(columns={"index":"rating", "rating":"count"},inplace=True)
ratings_count
# Out:
#       rating  count
# 0      TV-MA   2863
# 1      TV-14   1931
# 2      TV-PG    806
# 3          R    665
# 4      PG-13    386
# 5       TV-Y    280
# 6      TV-Y7    271
# 7         PG    247
# 8       TV-G    194
# 9         NR     84
# 10         G     39
# 11  TV-Y7-FV      6
# 12        UR      5
# 13     NC-17      3

# %%
plt.figure(figsize=(12,10))
sns.barplot(ratings_count["rating"],ratings_count["count"],palette = "viridis")
plt.xlabel("Ratings",fontsize=14)
plt.ylabel("Count", fontsize=14)
plt.title("Numbers of ratings", fontsize=14)
# Out:
# Text(0.5, 1.0, 'Numbers of ratings')

# %%
df = df[df["date_added"].notna()]

# %%
df["year_added"] = df["date_added"].apply(lambda x:x.split(" ")[-1])
df["year_added"]
# Out:
# <ipython-input-246-57b88abe4773>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["year_added"] = df["date_added"].apply(lambda x:x.split(" ")[-1])
# 0       2020
# 1       2016
# 2       2018
# 3       2017
# 4       2020
#         ...
# 7782    2020
# 7783    2019
# 7784    2020
# 7785    2020
# 7786    2020
# Name: year_added, Length: 7777, dtype: object

# %%
df["month_added"] = df["date_added"].apply(lambda x:x.split(" ")[0])
df["month_added"]
# Out:
# <ipython-input-247-f3697b712813>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["month_added"] = df["date_added"].apply(lambda x:x.split(" ")[0])
# 0          August
# 1        December
# 2        December
# 3        November
# 4         January
#           ...
# 7782      October
# 7783        March
# 7784    September
# 7785      October
# 7786        March
# Name: month_added, Length: 7777, dtype: object

# %%
year_added = pd.DataFrame(df["year_added"].value_counts().reset_index())
year_added.rename(columns={"index":"year", "year_added":"count"},inplace=True)
year_added = year_added.sort_values("year", ascending=True)
year_added
# Out:
#     year  count
# 12  2008      2
# 11  2009      2
# 13  2010      1
# 8   2011     13
# 10  2012      3
# 9   2013     11
# 7   2014     25
# 6   2015     88
# 4   2016    443
# 3   2017   1225
# 2   2018   1685
# 0   2019   2153
# 1   2020   2009
# 5   2021    117

# %%
plt.figure(figsize=(10,12))
plt.plot(year_added["year"], year_added["count"], marker='o', markersize=6)
plt.xlabel("Year", fontsize=14)
plt.ylabel("Count", fontsize=14)
plt.title("Numbers of shows and movies added on Netflix per year", fontsize=14)
plt.show()

# %%
month_added = pd.DataFrame(df["month_added"].value_counts().reset_index())
month_added.rename(columns={"index":"month", "month_added":"count"},inplace=True)
nan_value = float("NaN")
month_added.replace("",nan_value, inplace=True)
month_added.dropna(subset=["month"], inplace=True)
month_added
# Out:
#         month  count
# 0    December    817
# 1     October    780
# 2     January    746
# 3    November    730
# 4       March    661
# 5   September    614
# 6      August    612
# 7       April    596
# 8        July    592
# 9        June    538
# 10        May    537
# 11   February    466

# %%
plt.figure(figsize=(10,12))
colors = ["seagreen", "red", "plum","pink", "crimson", "orange", "salmon", "chocolate", "bisque", "royalblue", "lightsteelblue", "aqua" ]
plt.pie(month_added["count"],labels= month_added["month"], colors= colors, autopct='%1.2f%%', shadow=True, startangle=140)
plt.title("Percentage of shows and movies added on Netflix per month", fontsize=14)
plt.axis('equal', fontsize=14)
plt.show()
# Out:
# <ipython-input-251-19ae51d5f0fd>:5: MatplotlibDeprecationWarning: Passing unsupported keyword arguments to axis() will raise a TypeError in 3.3.
#   plt.axis('equal', fontsize=14)

# %%
top_10_country = pd.DataFrame(df["country"].value_counts().head(10).reset_index())
top_10_country.rename(columns = {"index":"Country", "country":"count"}, inplace=True)
top_10_country
# Out:
#           Country  count
# 0   United States   2549
# 1           India    923
# 2  United Kingdom    396
# 3           Japan    225
# 4     South Korea    183
# 5          Canada    177
# 6           Spain    134
# 7          France    115
# 8           Egypt    101
# 9          Turkey    100

# %%
plt.figure(figsize=(10,12))
sns.barplot(top_10_country["count"],top_10_country["Country"])
plt.title("Top 10 countries with the most Netflix content", fontsize = 14)
plt.xlabel("Count", fontsize=14)
plt.ylabel("Country", fontsize=14)
plt.show()

# %%
movie_filtered = df[df["type"] == "Movie"]
movie_filtered.head()
# Out:
#   show_id   type  title        country         date_added  release_year  \
# 1      s2  Movie   7:19         Mexico  December 23, 2016          2016
# 2      s3  Movie  23:59      Singapore  December 20, 2018          2011
# 3      s4  Movie      9  United States  November 16, 2017          2009
# 4      s5  Movie     21  United States    January 1, 2020          2008
# 6      s7  Movie    122          Egypt       June 1, 2020          2019
#
#   rating duration                                              genre  \
# 1  TV-MA   93 min                       Dramas, International Movies
# 2      R   78 min                Horror Movies, International Movies
# 3  PG-13   80 min  Action & Adventure, Independent Movies, Sci-Fi...
# 4  PG-13  123 min                                             Dramas
# 6  TV-MA   95 min                Horror Movies, International Movies
#
#   year_added month_added
# 1       2016    December
# 2       2018    December
# 3       2017    November
# ...

# %%
movie_duration = movie_filtered["duration"].apply(lambda x:x.split(" ")[0]).reset_index()
movie_duration.drop(columns={"index"}, inplace=True)
movie_duration
# Out:
#      duration
# 0          93
# 1          78
# 2          80
# 3         123
# 4          95
# ...       ...
# 5372       88
# 5373       99
# 5374      111
# 5375       44
# 5376       90
#
# [5377 rows x 1 columns]

# %%
plt.figure(figsize=(10,12))
sns.set_style('darkgrid')
sns.distplot(movie_duration["duration"],kde = False, bins=80)
plt.title("Duration of movie in minutes", fontsize = 14)
plt.xlabel("Movie duration in minutes", fontsize = 14)
plt.ylabel("Count", fontsize = 14)
plt.show()

# %%
tv_show_filtered = df[df["type"] == "TV Show"]
tv_show_filtered.head()
# Out:
#    show_id     type   title                country         date_added  \
# 0       s1  TV Show      3%                 Brazil    August 14, 2020
# 5       s6  TV Show      46                 Turkey       July 1, 2017
# 11     s12  TV Show    1983  Poland, United States  November 30, 2018
# 12     s13  TV Show    1994                 Mexico       May 17, 2019
# 16     s17  TV Show  Feb-09                    NaN     March 20, 2019
#
#     release_year rating   duration  \
# 0           2020  TV-MA  4 Seasons
# 5           2016  TV-MA   1 Season
# 11          2018  TV-MA   1 Season
# 12          2019  TV-MA   1 Season
# 16          2018  TV-14   1 Season
#
#                                                 genre year_added month_added
# 0   International TV Shows, TV Dramas, TV Sci-Fi &...       2020      August
# 5     International TV Shows, TV Dramas, TV Mysteries       2017        July
# 11  Crime TV Shows, International TV Shows, TV Dramas       2018    November
# ...

# %%
show_duration = tv_show_filtered.groupby(["duration"])["type"].count().reset_index()
show_duration = show_duration.rename(columns ={"type": "count"}).sort_values("count", ascending=False)
show_duration
# Out:
#       duration  count
# 0     1 Season   1608
# 7    2 Seasons    378
# 8    3 Seasons    183
# 9    4 Seasons     86
# 10   5 Seasons     57
# 11   6 Seasons     30
# 12   7 Seasons     19
# 13   8 Seasons     18
# 14   9 Seasons      8
# 1   10 Seasons      5
# 2   11 Seasons      2
# 3   12 Seasons      2
# 5   15 Seasons      2
# 4   13 Seasons      1
# 6   16 Seasons      1

# %%
plt.figure(figsize=(10,12))
sns.barplot(show_duration["duration"], show_duration["count"],palette = "icefire")
plt.title("Number of season for Tv Shows",fontsize=14)
plt.xlabel("Number of season",fontsize=14)
plt.ylabel("Count", fontsize=14)
plt.xticks(rotation=75)
plt.show()
